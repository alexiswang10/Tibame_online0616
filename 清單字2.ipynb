# %% [markdown]
# <a href="https://colab.research.google.com/github/alexiswang10/Tibame_online0616/blob/main/%E6%B8%85%E5%96%AE%E5%AD%972.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
scores = [80, 60, 90, 20, 100]

count = 0
i = 0
# while i < len(scores):  s = scores[i]
# 方便做連結或查詢用但前提要有順序如"list"

while i < len(scores):
    s = scores[i]
    if s >= 60:
        count = count + 1
    i = i + 1
print(count)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# for in
# 以下是沒順序隨意拿拿


count = 0
  for s in scores:
  if s >= 60:
  count = count + 1
  print(count)
# Out:
# 4

# %%
# 對比while的一到加十方法

# 1 + 2 + 3... + 10
total = 0
i = 0
while i < 10:
    total = total + (i + 1)
    print(total)
    i = i + 1
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 對比while的一到加十方法

# 1 + 2 + 3... + 10
total = 0
i = 0
for i in range(10):
    total = total + (i + 1)
    print(total)
    i = i + 1
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# for in


# for i in reang

  # 第二種狀況呢是固定次數型的迴圈
  # 第二種狀況呢是固定次數型的迴圈
  # 譬如說我們玩10把
  # 或者是從1數到10
  # 你就是for i in range
  # 後面次數 名稱你就永遠用i
  # 跟你以前的習慣一模一樣
  # 那你的次數就在range的小括號裡面

# while

# 例如剪刀石頭布
