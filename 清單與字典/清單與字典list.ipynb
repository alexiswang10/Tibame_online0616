# %% [markdown]
# <a href="https://colab.research.google.com/github/alexiswang10/Tibame_online0616/blob/main/%E6%B8%85%E5%96%AE%E8%88%87%E5%AD%97%E5%85%B8list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 查詢一段
# socore=[30, 50, 80, 60, 90]
socore=[30, 50, 80, 60, 90]
print(socore[1:3])

# %% [markdown]
# ![Snipaste_2025-06-25_00-21-54.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
