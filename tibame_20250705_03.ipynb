# %% [markdown]
# <a href="https://colab.research.google.com/github/alexiswang10/Tibame_online0616/blob/main/tibame_20250705_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request as req
import pandas as pd

url = "https://github.com/Elwing-Chou/tibame_online_0616/raw/refs/heads/main/tabelog.csv"
req.urlretrieve(url, "tabelog.csv")
df = pd.read_csv("tabelog.csv", encoding="utf-8", index_col=0)
df
# Out:
#                                                    en  \
# 0                                              Bon.nu
# 1                                         AIGRE DOUCE
# 2                                     a tes souhaits!
# 3                                L'Atelier à Ma Façon
# 4                                    Patisserie Ryoko
# ..                                                ...
# 95                             Criollo Nakameguro Ten
# 96                 Le Grenier à Pan Koji Chiyocho Ten
# 97  LA BOUTIQUE de Joel Robushon Ebisu Garden Plac...
# 98                                            Chimoto
# 99                         Fiorentina Pastry Boutique
#
#                                                  href  rating  \
# 0   https://tabelog.com/tw/tokyo/A1304/A130401/131...    4.28
# 1   https://tabelog.com/tw/tokyo/A1305/A130502/130...    4.03
# 2   https://tabelog.com/tw/tokyo/A1320/A132001/130...    4.01
# 3   https://tabelog.com/tw/tokyo/A1317/A131715/132...    4.00
# 4   https://tabelog.com/tw/tokyo/A1316/A131603/131...    3.99
# ..                                                ...     ...
# 95  https://tabelog.com/tw/tokyo/A1317/A131701/130...    3.77
# 96  https://tabelog.com/tw/tokyo/A1308/A130803/130...    3.77
# 97  https://tabelog.com/tw/tokyo/A1303/A130302/130...    3.77
# 98  https://tabelog.com/tw/tokyo/A1317/A131702/130...    3.77
# 99  https://tabelog.com/tw/tokyo/A1307/A130701/130...    3.77
#
#                   area_genre             dinner_price  \
# 0           參宮橋車站 / 法式料理, 蛋糕  JPY 50,000 - JPY 59,999
# 1             目白車站 / 蛋糕, 馬卡龍    JPY 1,000 - JPY 1,999
# 2             西荻窪車站 / 蛋糕, 甜點                - JPY 999
# 3            上野毛車站 / 甜點, 咖啡店    JPY 4,000 - JPY 4,999
# 4       高輪台車站 / 蛋糕, 泡芙, 西式甜點                        -
# ..                       ...                      ...
# 95      中目黑車站 / 蛋糕, 巧克力, 馬卡龍    JPY 4,000 - JPY 4,999
# 96       半藏門車站 / 麵包, 三明治, 蛋糕                - JPY 999
# 97       惠比壽車站 / 麵包, 蛋糕, 三明治    JPY 1,000 - JPY 1,999
# 98  都立大學車站 / 日式點心, 日式甜點店, 剉冰    JPY 1,000 - JPY 1,999
# 99       六本木車站 / 蛋糕, 麵包, 巧克力    JPY 1,000 - JPY 1,999
#
#                 lunch_price             holiday
# 0   JPY 50,000 - JPY 59,999                   -
# 1     JPY 1,000 - JPY 1,999            星期一, 星期二
# 2                 - JPY 999            星期一, 星期二
# 3     JPY 4,000 - JPY 4,999                   -
# 4                 - JPY 999  星期一, 星期二, 星期三, 星期四
# ..                      ...                 ...
# 95                        -                   -
# 96                - JPY 999                   -
# 97    JPY 1,000 - JPY 1,999                   -
# 98                - JPY 999            星期三, 星期四
# 99    JPY 1,000 - JPY 1,999                   -
#
# [100 rows x 7 columns]

# %%
# 可以掛接雲端硬碟來當你的永久儲存
# df.to_csv("drive/MyDrive/tabelog0705.csv", encoding="utf-8")

# %% [markdown]
# ```
# pandas兩大操作
# 1. 過濾(filter): 帶入跟你資料筆數依樣多的True/False
# 2. 轉換(apply):
#
#
# ```

# %%
df["rating"] * 2
# Out:
# 0     8.56
# 1     8.06
# 2     8.02
# 3     8.00
# 4     7.98
#       ...
# 95    7.54
# 96    7.54
# 97    7.54
# 98    7.54
# 99    7.54
# Name: rating, Length: 100, dtype: float64

# %%
# apply(轉換流程): 轉換流程是一個錦囊(不加小括號)
rating_2 = df["rating"] * 2
rating_2.apply(round)

# %%
def flow(n):
    return round(n * 2, 1)
df["rating"].apply(flow)

# %% [markdown]
# ```
# 這裡一個值要變出兩行
# pd.DataFrame: 二維, 有行有列的
# pd.Series: 一維, 一行/一列
# ```

# %%
def flow(n):
    return pd.Series({"a":n, "b":2*n})
df["rating"].apply(flow)

# %%
def flow(data):
    data_split = data.split(" / ")
    if len(data_split) == 1:
        area = data_split[0]
        genre = "-"
    else:
        area = data_split[0]
        genre = data_split[1]
    return pd.Series({"area":area, "genre":genre})

df[["area", "genre"]] = df["area_genre"].apply(flow)
df

# %%
holiday = {
    "星期一":"Y",
    "星期二":"Y",
    "星期三":"Y",
    "星期四":"Y",
    "星期五":"Y",
    "星期六":"Y",
    "星期日":"Y",
}
def flow(data):
    for key in holiday:
        if key in data:
            holiday[key] = "N"
    return pd.Series(holiday)

df[list(holiday.keys())] = df["holiday"].apply(flow)
df
# Out:
#                                                    en  \
# 0                                              Bon.nu
# 1                                         AIGRE DOUCE
# 2                                     a tes souhaits!
# 3                                L'Atelier à Ma Façon
# 4                                    Patisserie Ryoko
# ..                                                ...
# 95                             Criollo Nakameguro Ten
# 96                 Le Grenier à Pan Koji Chiyocho Ten
# 97  LA BOUTIQUE de Joel Robushon Ebisu Garden Plac...
# 98                                            Chimoto
# 99                         Fiorentina Pastry Boutique
#
#                                                  href  rating  \
# 0   https://tabelog.com/tw/tokyo/A1304/A130401/131...    4.28
# 1   https://tabelog.com/tw/tokyo/A1305/A130502/130...    4.03
# 2   https://tabelog.com/tw/tokyo/A1320/A132001/130...    4.01
# 3   https://tabelog.com/tw/tokyo/A1317/A131715/132...    4.00
# 4   https://tabelog.com/tw/tokyo/A1316/A131603/131...    3.99
# ..                                                ...     ...
# 95  https://tabelog.com/tw/tokyo/A1317/A131701/130...    3.77
# 96  https://tabelog.com/tw/tokyo/A1308/A130803/130...    3.77
# 97  https://tabelog.com/tw/tokyo/A1303/A130302/130...    3.77
# 98  https://tabelog.com/tw/tokyo/A1317/A131702/130...    3.77
# 99  https://tabelog.com/tw/tokyo/A1307/A130701/130...    3.77
#
#                   area_genre             dinner_price  \
# 0           參宮橋車站 / 法式料理, 蛋糕  JPY 50,000 - JPY 59,999
# 1             目白車站 / 蛋糕, 馬卡龍    JPY 1,000 - JPY 1,999
# 2             西荻窪車站 / 蛋糕, 甜點                - JPY 999
# 3            上野毛車站 / 甜點, 咖啡店    JPY 4,000 - JPY 4,999
# 4       高輪台車站 / 蛋糕, 泡芙, 西式甜點                        -
# ..                       ...                      ...
# 95      中目黑車站 / 蛋糕, 巧克力, 馬卡龍    JPY 4,000 - JPY 4,999
# 96       半藏門車站 / 麵包, 三明治, 蛋糕                - JPY 999
# 97       惠比壽車站 / 麵包, 蛋糕, 三明治    JPY 1,000 - JPY 1,999
# 98  都立大學車站 / 日式點心, 日式甜點店, 剉冰    JPY 1,000 - JPY 1,999
# 99       六本木車站 / 蛋糕, 麵包, 巧克力    JPY 1,000 - JPY 1,999
#
#                 lunch_price             holiday    area            genre 星期一  \
# 0   JPY 50,000 - JPY 59,999                   -   參宮橋車站         法式料理, 蛋糕   Y
# 1     JPY 1,000 - JPY 1,999            星期一, 星期二    目白車站          蛋糕, 馬卡龍   N
# 2                 - JPY 999            星期一, 星期二   西荻窪車站           蛋糕, 甜點   N
# 3     JPY 4,000 - JPY 4,999                   -   上野毛車站          甜點, 咖啡店   N
# 4                 - JPY 999  星期一, 星期二, 星期三, 星期四   高輪台車站     蛋糕, 泡芙, 西式甜點   N
# ..                      ...                 ...     ...              ...  ..
# 95                        -                   -   中目黑車站     蛋糕, 巧克力, 馬卡龍   N
# 96                - JPY 999                   -   半藏門車站      麵包, 三明治, 蛋糕   N
# 97    JPY 1,000 - JPY 1,999                   -   惠比壽車站      麵包, 蛋糕, 三明治   N
# 98                - JPY 999            星期三, 星期四  都立大學車站  日式點心, 日式甜點店, 剉冰   N
# 99    JPY 1,000 - JPY 1,999                   -   六本木車站      蛋糕, 麵包, 巧克力   N
#
#    星期二 星期三 星期四 星期五 星期六 星期日
# 0    Y   Y   Y   Y   Y   Y
# 1    N   Y   Y   Y   Y   Y
# 2    N   Y   Y   Y   Y   Y
# 3    N   Y   Y   Y   Y   Y
# 4    N   N   N   Y   Y   Y
# ..  ..  ..  ..  ..  ..  ..
# 95   N   N   N   N   N   N
# 96   N   N   N   N   N   N
# 97   N   N   N   N   N   N
# 98   N   N   N   N   N   N
# 99   N   N   N   N   N   N
#
# [100 rows x 16 columns]

# %%
df["holiday"].value_counts()
# Out:
# holiday
# -                          38
# 星期一, 星期二                   10
# 星期二, 星期三                    6
# 星期日, 節假日                    6
# 星期三                         5
# 星期日                         5
# 星期一                         4
# 星期二                         4
# 星期一, 星期日                    3
# 星期三, 星期四                    3
# 星期一, 星期二, 星期三, 星期四          2
# 星期六, 星期日, 節假日               2
# 星期一, 星期日, 節假日               2
# 星期一, 星期二, 星期日               1
# 星期四                         1
# 星期三, 星期六, 星期日, 節假日          1
# 星期一, 星期二, 星期三, 星期四, 星期五     1
# 星期一, 星期二, 星期三               1
# 星期一, 星期二, 星期三, 星期四, 星期日     1
# 星期六, 星期日                    1
# 星期一, 星期四                    1
# 星期三, 星期日                    1
# 星期一, 星期二, 星期三, 星期日          1
# Name: count, dtype: int64

# %% [markdown]
# ```
# Everything is an object: 任何東西都是有型態的, 都有他配合的操作
#
# 字典[key]
#
# print(3+2)
#
# print: 函式型態
# (3+2): 針對這型態的操作
#
# !!! 函式是一種型態
#
# 函式: 常用的幾句程式碼包在一起變成一份SOP
#
# print: 步驟型態(還沒做)
# (3+2): 真的把步驟操作一遍得到結果
#
# ```

# %%
def add(n1, n2):
    ans = n1 + n2
    return ans
b = add
b(3, 5)

import random
def realrandom(t):
    if t == 0:
        return random.randint
    else:
        return random.uniform

realrandom(1)(3, 5)
# Out:
# 3.645866854815284
